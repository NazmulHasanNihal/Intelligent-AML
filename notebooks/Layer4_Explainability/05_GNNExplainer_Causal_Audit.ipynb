# %% [markdown]
# # Layer 4: Causal Auditing (Explainable AI)
# ## GNNExplainer & PyVis
# Objective: Isolate the exact transaction pathways triggering the AML alerts to output high-fidelity visual heatmaps for EU AI Act compliance.

# %%
from torch_geometric.explain import Explainer, GNNExplainer
import pyvis

print("Layer 4: Explainability Initialization Complete")
